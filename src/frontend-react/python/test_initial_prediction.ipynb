# %%
# Out:
# /Users/tk20/Desktop/APCOMP215/ac215_Group_127_2473879/src/frontend-react/python/test_initial_pred_1765158543
# No case history file found for case test_initial_pred_1765158543, using default.
# No conversation history file found for case test_initial_pred_1765158543, using default.
# No demographics file found for case test_initial_pred_1765158543, using default.
# Processing initial prediction for case test_initial_pred_1765158543...
#   → Loading and saving image...
#     Image path: /Users/tk20/Desktop/APCOMP215/data/sample_imgs/trial/a.png
#     Path exists: True
# Case ID: test_initial_pred_1765158543
# Image path: /Users/tk20/Desktop/APCOMP215/data/sample_imgs/trial/a.png
#     ✓ Image saved to: /Users/tk20/Desktop/APCOMP215/ac215_Group_127_2473879/src/frontend-react/python/test_initial_pred_1765158543/images/image_0001.png
#   → Running local ML model for embeddings...
#     Encoding image: <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2816x1536 at 0x105AE7F70>
# ...
