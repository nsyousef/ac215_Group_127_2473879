# %%
# !pip install ipython==8.10.0
# %load_ext autoreload
# %autoreload 2
from main import initialize_model
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 784.3/784.3 kB 17.5 MB/s eta 0:00:0000:01
# ...
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipykernel==6.17.1, but you have ipykernel 7.0.1 which is incompatible.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 8.10.0 which is incompatible.
# notebook 6.5.7 requires jupyter-client<8,>=5.3.4, but you have jupyter-client 8.6.3 which is incompatible.
# jupyter-kernel-gateway 2.5.2 requires jupyter-client<8.0,>=5.2.0, but you have jupyter-client 8.6.3 which is incompatible.
# ...

# %%
model_dict = initialize_model(config_path="configs/TEMPLATE.yaml")
# Out:
# 2025-10-14 22:43:23,691 - utils - INFO - Using device: cuda
# INFO:utils:Using device: cuda
# 2025-10-14 22:43:23,710 - utils - INFO - Loaded configuration from: configs/TEMPLATE.yaml
# INFO:utils:Loaded configuration from: configs/TEMPLATE.yaml
# 2025-10-14 22:43:23,712 - utils - INFO - Loading metadata from: gs://derma-datasets-2/final/metadata_all_harmonized.csv
# INFO:utils:Loading metadata from: gs://derma-datasets-2/final/metadata_all_harmonized.csv
# 2025-10-14 22:43:23,714 - utils - INFO - Loading metadata from: gs://derma-datasets-2/final/metadata_all_harmonized.csv
# INFO:utils:Loading metadata from: gs://derma-datasets-2/final/metadata_all_harmonized.csv
# 2025-10-14 22:43:24,689 - utils - INFO - Total images loaded: 16,387
# INFO:utils:Total images loaded: 16,387
# 2025-10-14 22:43:24,696 - utils - INFO - Labels with <= 100 images: 25
# INFO:utils:Labels with <= 100 images: 25
# 2025-10-14 22:43:24,703 - utils - INFO - Images after filtering: 13,180
# ...

# %%
trainer = model_dict['trainer']
trainer.train()
# Out:
# 2025-10-14 22:43:50,320 - utils - INFO - Starting training for 100 epochs...
# INFO:utils:Starting training for 100 epochs...
# 2025-10-14 22:43:50,321 - utils - INFO - Starting from epoch: 0
# INFO:utils:Starting from epoch: 0
# 2025-10-14 22:43:50,322 - utils - INFO - Optimizer: adam
# INFO:utils:Optimizer: adam
# 2025-10-14 22:43:50,325 - utils - INFO - Learning rate: 0.001
# INFO:utils:Learning rate: 0.001
# Epoch 1 - Training:   0%|          | 0/576 [00:00<?, ?it/s]
# Time taken to get 1 image: 0.9929516315460205
# Time taken to get 1 image: 1.0169429779052734
# Time taken to get 1 image: 0.8814043998718262
# Time taken to get 1 image: 0.8068723678588867
# Time taken to get 1 image: 1.4752159118652344
# Time taken to get 1 image: 1.027467966079712
# Time taken to get 1 image: 0.856619119644165
# Time taken to get 1 image: 1.0889215469360352
# Time taken to get 1 image: 0.878063440322876
# Time taken to get 1 image: 1.0220999717712402
# ...
