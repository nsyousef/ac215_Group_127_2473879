# %% [markdown]
# # Inspect Bucket
#
# This Jupyter Notebook is for inspecting the bucket, so I don't have to download stuff.

# %%
from google.cloud import storage
import io
from PIL import Image
import pandas as pd
from io import StringIO, BytesIO
import requests
import re
import matplotlib.pyplot as plt
import concurrent.futures
from tqdm import tqdm
from urllib.parse import urlparse
import random
import os

pd.options.display.max_columns = None
pd.options.display.max_rows = None


client = storage.Client()
bucket = client.bucket('derma-datasets-2')

def view_image(path, bucket):
    blob = bucket.blob(path)
    img_bytes = blob.download_as_bytes()
    img = Image.open(BytesIO(img_bytes))
    img.show()

# %% [markdown]
# ## Inspect Images

# %%
# check size of current final images, so I know how to standardize them
FINAL_PATH = 'final'
FINAL_IMG_PATH = 'final/imgs'
RAW_PATH = 'raw/fitzpatrick17k/'
blobs = bucket.list_blobs(prefix=FINAL_IMG_PATH)

counter = 0
for blob in blobs:
    if counter >= 10:
        break
    if not blob.name.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.gif', '.webp', '.tiff')):
        continue  # skip non-image files
    
    image_data = blob.download_as_bytes()
    
    # Open with Pillow
    with Image.open(BytesIO(image_data)) as img:
        width, height = img.size
        print(f"{blob.name}: {width}x{height}")
    counter += 1
# Out:
# final/imgs/SCIN_-1001492676369731180.png: 810x1080
# final/imgs/SCIN_-1003800477193786941.png: 810x845
# final/imgs/SCIN_-1005922060850163675.png: 811x1080
# final/imgs/SCIN_-1009086705875443190.png: 978x565
# final/imgs/SCIN_-1009810686742517529.png: 805x275
# final/imgs/SCIN_-1010272928122958162.png: 810x1080
# final/imgs/SCIN_-1010754336982699838.png: 404x977
# final/imgs/SCIN_-101168089788221310.png: 139x234
# final/imgs/SCIN_-1013329915718011639.png: 810x1080
# final/imgs/SCIN_-1013370714954869987.png: 1080x810

# %% [markdown]
# It looks like all the images are different sizes. Very well then. I will also just copy the Fitzpatrick images there, without resizing them.

# %% [markdown]
# ## Metadata CSV

# %%
meta_csv_blob = bucket.blob(os.path.join(FINAL_PATH, 'metadata.csv'))
meta_csv_data = meta_csv_blob.download_as_text()
meta_csv = pd.read_csv(StringIO(meta_csv_data))

# %%
meta_csv.head()
# Out:
#    Unnamed: 0             image_id  \
# 0           0 -3205742176803893704
# 1           1 -4762289084741430925
# 2           2 -4027806997035329030
# 3           3 -3799298995660217860
# 4           4 -5881426422999442186
#
#                                   unharmonized_label dataset  confidence  \
# 0                     Inflicted skin lesions, Eczema    SCIN           4
# 1                       Prurigo nodularis, SCC/SCCIS    SCIN           4
# 2                                           Impetigo    SCIN           2
# 3  Lichen planus/lichenoid eruption, Folliculitis...    SCIN           1
# 4  Lichen planus/lichenoid eruption, Folliculitis...    SCIN           1
#
#                    save_name
# 0  SCIN_-3205742176803893704
# 1  SCIN_-4762289084741430925
# 2  SCIN_-4027806997035329030
# 3  SCIN_-3799298995660217860
# 4  SCIN_-5881426422999442186

# %%
# check for duplicates in the existing metadata
meta_csv[meta_csv.duplicated(subset=["image_id", "dataset"], keep=False)].sort_values("image_id")
# Out:
#       Unnamed: 0             image_id           unharmonized_label dataset  \
# 289          289 -9111307368692396870                         Acne    SCIN
# 3775        3775 -9111307368692396870                         Acne    SCIN
# 3194        3194 -9111307368692396870                         Acne    SCIN
# 3579        3579 -8707418133635013822  Allergic Contact Dermatitis    SCIN
# 5626        5626 -8707418133635013822  Allergic Contact Dermatitis    SCIN
# 5105        5105 -8351498747234518768          Perioral Dermatitis    SCIN
# 6190        6190 -8351498747234518768                       Eczema    SCIN
# 2956        2956  -737002406762138892               Herpes Simplex    SCIN
# 1172        1172  -737002406762138892               Herpes Simplex    SCIN
# 1938        1938   -25353211408586438                 Folliculitis    SCIN
# 449          449   -25353211408586438                 Folliculitis    SCIN
# 5106        5106   265617434552206306          Perioral Dermatitis    SCIN
# 6191        6191   265617434552206306                       Eczema    SCIN
# 3580        3580  1851972142048297272  Allergic Contact Dermatitis    SCIN
# 5627        5627  1851972142048297272  Allergic Contact Dermatitis    SCIN
# 2957        2957  4013268428021902865               Herpes Simplex    SCIN
# 1173        1173  4013268428021902865               Herpes Simplex    SCIN
# 514          514  4166674568332648445                      Rosacea    SCIN
# 4726        4726  4166674568332648445                      Rosacea    SCIN
# 1939        1939  8270654112785798156                 Folliculitis    SCIN
# 450          450  8270654112785798156                 Folliculitis    SCIN
# 1174        1174  9068834759287693167               Herpes Simplex    SCIN
# 2958        2958  9068834759287693167               Herpes Simplex    SCIN
#
#       confidence                  save_name
# 289            3  SCIN_-9111307368692396870
# 3775           4  SCIN_-9111307368692396870
# 3194           5  SCIN_-9111307368692396870
# 3579           3  SCIN_-8707418133635013822
# 5626           4  SCIN_-8707418133635013822
# 5105           3  SCIN_-8351498747234518768
# 6190           4  SCIN_-8351498747234518768
# 2956           4   SCIN_-737002406762138892
# 1172           3   SCIN_-737002406762138892
# 1938           4    SCIN_-25353211408586438
# 449            4    SCIN_-25353211408586438
# 5106           3    SCIN_265617434552206306
# 6191           4    SCIN_265617434552206306
# 3580           3   SCIN_1851972142048297272
# 5627           4   SCIN_1851972142048297272
# 2957           4   SCIN_4013268428021902865
# 1173           3   SCIN_4013268428021902865
# 514            4   SCIN_4166674568332648445
# 4726           5   SCIN_4166674568332648445
# 1939           4   SCIN_8270654112785798156
# 450            4   SCIN_8270654112785798156
# 1174           3   SCIN_9068834759287693167
# 2958           4   SCIN_9068834759287693167

# %%
scin_meta_csv_blob = bucket.blob(os.path.join(FINAL_PATH, 'SCIN_text_metadata.csv'))
scin_meta_csv_data = scin_meta_csv_blob.download_as_text()
scin_meta_csv = pd.read_csv(StringIO(scin_meta_csv_data))

# %%
scin_meta_csv.head()
# Out:
#    Unnamed: 0 dermatologist_gradable_for_skin_condition_1  \
# 0           0        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 1           1        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 2           2        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 3           3        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 4           4        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
#
#   dermatologist_gradable_for_skin_condition_2  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   dermatologist_gradable_for_skin_condition_3  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#           dermatologist_skin_condition_on_label_name  \
# 0  ['Inflicted skin lesions', 'Eczema', 'Irritant...
# 1  ['Prurigo nodularis', 'Actinic Keratosis', 'SC...
# 2  ['Impetigo', 'Herpes Zoster', 'Bullous dermati...
# 3  ['Lichen planus/lichenoid eruption', 'Follicul...
# 4  ['Lichen planus/lichenoid eruption', 'Follicul...
#
#   dermatologist_skin_condition_confidence  \
# 0                               [4, 4, 3]
# 1                               [4, 3, 4]
# 2                               [2, 1, 1]
# 3                               [1, 1, 1]
# 4                               [1, 1, 1]
#
#                        weighted_skin_condition_label  \
# 0  {'Inflicted skin lesions': 0.41, 'Eczema': 0.4...
# 1  {'Prurigo nodularis': 0.41, 'SCC/SCCIS': 0.41,...
# 2  {'Impetigo': 0.55, 'Herpes Zoster': 0.23, 'Bul...
# 3  {'Lichen planus/lichenoid eruption': 0.33, 'Fo...
# 4  {'Lichen planus/lichenoid eruption': 0.33, 'Fo...
#
#   dermatologist_gradable_for_fitzpatrick_skin_type_1  \
# 0                                                YES
# 1                                                YES
# 2                                                YES
# 3                                                YES
# 4                                                YES
#
#   dermatologist_gradable_for_fitzpatrick_skin_type_2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   dermatologist_gradable_for_fitzpatrick_skin_type_3  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   dermatologist_fitzpatrick_skin_type_label_1  \
# 0                                        FST2
# 1                                        FST1
# 2                                        FST4
# 3                                        FST1
# 4                                        FST1
#
#   dermatologist_fitzpatrick_skin_type_label_2  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   dermatologist_fitzpatrick_skin_type_label_3  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   gradable_for_monk_skin_tone_india gradable_for_monk_skin_tone_us  \
# 0                              True                           True
# 1                              True                           True
# 2                              True                           True
# 3                              True                           True
# 4                              True                           True
#
#    monk_skin_tone_label_india  monk_skin_tone_label_us source release  year  \
# 0                         2.0                      1.0   SCIN   1.0.0  2023
# 1                         3.0                      3.0   SCIN   1.0.0  2023
# 2                         3.0                      4.0   SCIN   1.0.0  2023
# 3                         1.0                      1.0   SCIN   1.0.0  2023
# 4                         1.0                      1.0   SCIN   1.0.0  2023
#
#       age_group          sex_at_birth fitzpatrick_skin_type  \
# 0   AGE_UNKNOWN  OTHER_OR_UNSPECIFIED                   NaN
# 1   AGE_UNKNOWN  OTHER_OR_UNSPECIFIED                   NaN
# 2  AGE_18_TO_29                  MALE       NONE_IDENTIFIED
# 3  AGE_40_TO_49                FEMALE                  FST3
# 4  AGE_40_TO_49                FEMALE                  FST3
#
#   race_ethnicity_american_indian_or_alaska_native race_ethnicity_asian  \
# 0                                             NaN                  NaN
# 1                                             NaN                  NaN
# 2                                             NaN                  NaN
# 3                                             NaN                  NaN
# 4                                             NaN                  NaN
#
#   race_ethnicity_black_or_african_american  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   race_ethnicity_hispanic_latino_or_spanish_origin  \
# 0                                              NaN
# 1                                              NaN
# 2                                              YES
# 3                                              NaN
# 4                                              NaN
#
#   race_ethnicity_middle_eastern_or_north_african  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   race_ethnicity_native_hawaiian_or_pacific_islander race_ethnicity_white  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2                                                NaN                  NaN
# 3                                                NaN                  YES
# 4                                                NaN                  YES
#
#   race_ethnicity_other_race race_ethnicity_prefer_not_to_answer  \
# 0                       NaN                                 NaN
# 1                       NaN                                 NaN
# 2                       NaN                                 NaN
# 3                       NaN                                 NaN
# 4                       NaN                                 NaN
#
#   textures_raised_or_bumpy textures_flat textures_rough_or_flaky  \
# 0                      YES           NaN                     NaN
# 1                      NaN           NaN                     NaN
# 2                      NaN           YES                     YES
# 3                      NaN           YES                     NaN
# 4                      NaN           YES                     NaN
#
#   textures_fluid_filled body_parts_head_or_neck body_parts_arm  \
# 0                   NaN                     NaN            NaN
# 1                   NaN                     NaN            NaN
# 2                   NaN                     NaN            YES
# 3                   NaN                     YES            YES
# 4                   NaN                     YES            YES
#
#   body_parts_palm body_parts_back_of_hand body_parts_torso_front  \
# 0             NaN                     NaN                    NaN
# 1             NaN                     NaN                    NaN
# 2             NaN                     NaN                    NaN
# 3             NaN                     YES                    YES
# 4             NaN                     YES                    YES
#
#   body_parts_torso_back body_parts_genitalia_or_groin body_parts_buttocks  \
# 0                   NaN                           NaN                 NaN
# 1                   NaN                           NaN                 NaN
# 2                   NaN                           NaN                 NaN
# 3                   YES                           YES                 YES
# 4                   YES                           YES                 YES
#
#   body_parts_leg body_parts_foot_top_or_side body_parts_foot_sole  \
# 0            NaN                         YES                  NaN
# 1            NaN                         NaN                  NaN
# 2            NaN                         NaN                  NaN
# 3            YES                         YES                  NaN
# 4            YES                         YES                  NaN
#
#   body_parts_other condition_symptoms_bothersome_appearance  \
# 0              NaN                                      NaN
# 1              NaN                                      NaN
# 2              NaN                                      NaN
# 3              NaN                                      NaN
# 4              NaN                                      NaN
#
#   condition_symptoms_bleeding condition_symptoms_increasing_size  \
# 0                         YES                                YES
# 1                         NaN                                NaN
# 2                         NaN                                YES
# 3                         NaN                                NaN
# 4                         NaN                                NaN
#
#   condition_symptoms_darkening condition_symptoms_itching  \
# 0                          NaN                        YES
# 1                          NaN                        NaN
# 2                          NaN                        YES
# 3                          NaN                        YES
# 4                          NaN                        YES
#
#   condition_symptoms_burning condition_symptoms_pain  \
# 0                        YES                     YES
# 1                        NaN                     NaN
# 2                        YES                     YES
# 3                        NaN                     NaN
# 4                        NaN                     NaN
#
#   condition_symptoms_no_relevant_experience other_symptoms_fever  \
# 0                                       NaN                  NaN
# 1                                       NaN                  NaN
# 2                                       NaN                  NaN
# 3                                       NaN                  NaN
# 4                                       NaN                  NaN
#
#   other_symptoms_chills other_symptoms_fatigue other_symptoms_joint_pain  \
# 0                   NaN                    NaN                       NaN
# 1                   NaN                    NaN                       NaN
# 2                   NaN                    NaN                       NaN
# 3                   NaN                    NaN                       NaN
# 4                   NaN                    NaN                       NaN
#
#   other_symptoms_mouth_sores other_symptoms_shortness_of_breath  \
# 0                        NaN                                NaN
# 1                        NaN                                NaN
# 2                        NaN                                NaN
# 3                        NaN                                NaN
# 4                        NaN                                NaN
#
#   other_symptoms_no_relevant_symptoms         related_category  \
# 0                                 YES                     RASH
# 1                                 NaN                      NaN
# 2                                 YES  OTHER_ISSUE_DESCRIPTION
# 3                                 YES                     RASH
# 4                                 YES                     RASH
#
#   condition_duration                             image_1_path  \
# 0            ONE_DAY  dataset/images/-3205742176803893704.png
# 1                NaN  dataset/images/-4762289084741430925.png
# 2  ONE_TO_FOUR_WEEKS  dataset/images/-4027806997035329030.png
# 3            ONE_DAY  dataset/images/-3799298995660217860.png
# 4            ONE_DAY  dataset/images/-3799298995660217860.png
#
#                               image_2_path  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3  dataset/images/-5881426422999442186.png
# 4  dataset/images/-5881426422999442186.png
#
#                              image_3_path image_1_shot_type image_2_shot_type  \
# 0                                     NaN          CLOSE_UP               NaN
# 1                                     NaN          CLOSE_UP               NaN
# 2                                     NaN          CLOSE_UP               NaN
# 3  dataset/images/5854025080806696361.png       AT_AN_ANGLE       AT_DISTANCE
# 4  dataset/images/5854025080806696361.png       AT_AN_ANGLE       AT_DISTANCE
#
#   image_3_shot_type                      combined_race  \
# 0               NaN                                NaN
# 1               NaN                                NaN
# 2               NaN  HISPANIC_LATINO_OR_SPANISH_ORIGIN
# 3          CLOSE_UP                              WHITE
# 4          CLOSE_UP                              WHITE
#
#   race_ethnicity_two_or_more_after_mitigation  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#                                               labels dataset  \
# 0                     Inflicted skin lesions, Eczema    SCIN
# 1                       Prurigo nodularis, SCC/SCCIS    SCIN
# 2                                           Impetigo    SCIN
# 3  Lichen planus/lichenoid eruption, Folliculitis...    SCIN
# 4  Lichen planus/lichenoid eruption, Folliculitis...    SCIN
#
#                    save_name  confidence             image_id  \
# 0  SCIN_-3205742176803893704           4 -3205742176803893704
# 1  SCIN_-4762289084741430925           4 -4762289084741430925
# 2  SCIN_-4027806997035329030           2 -4027806997035329030
# 3  SCIN_-3799298995660217860           1 -3799298995660217860
# 4  SCIN_-5881426422999442186           1 -5881426422999442186
#
#                                   unharmonized_label
# 0                     Inflicted skin lesions, Eczema
# 1                       Prurigo nodularis, SCC/SCCIS
# 2                                           Impetigo
# 3  Lichen planus/lichenoid eruption, Folliculitis...
# 4  Lichen planus/lichenoid eruption, Folliculitis...

# %% [markdown]
# ## Inspect Fitzpatrick CSV

# %%
fitz_meta_blob = bucket.blob(os.path.join(RAW_PATH, 'fitzpatrick17k.csv'))
fitz_meta_data = fitz_meta_blob.download_as_text()
fitz_meta_csv = pd.read_csv(StringIO(fitz_meta_data))

# %%
fitz_meta_csv.head()
# Out:
#                             md5hash  fitzpatrick_scale  fitzpatrick_centaur  \
# 0  5e82a45bc5d78bd24ae9202d194423f8                  3                    3
# 1  fa2911a9b13b6f8af79cb700937cc14f                  1                    1
# 2  d2bac3c9e4499032ca8e9b07c7d3bc40                  2                    3
# 3  0a94359e7eaacd7178e06b2823777789                  1                    1
# 4  a39ec3b1f22c08a421fa20535e037bba                  1                    1
#
#                              label nine_partition_label three_partition_label  \
# 0  drug induced pigmentary changes         inflammatory        non-neoplastic
# 1                  photodermatoses         inflammatory        non-neoplastic
# 2                   dermatofibroma        benign dermal                benign
# 3                        psoriasis         inflammatory        non-neoplastic
# 4                        psoriasis         inflammatory        non-neoplastic
#
#     qc                                                url  \
# 0  NaN  https://www.dermaamin.com/site/images/clinical...
# 1  NaN  https://www.dermaamin.com/site/images/clinical...
# 2  NaN  https://www.dermaamin.com/site/images/clinical...
# 3  NaN  https://www.dermaamin.com/site/images/clinical...
# 4  NaN  https://www.dermaamin.com/site/images/clinical...
#
#                                         url_alphanum
# 0  httpwwwdermaamincomsiteimagesclinicalpicmminoc...
# 1  httpwwwdermaamincomsiteimagesclinicalpicpphoto...
# 2  httpwwwdermaamincomsiteimagesclinicalpicdderma...
# 3  httpwwwdermaamincomsiteimagesclinicalpicppsori...
# 4  httpwwwdermaamincomsiteimagesclinicalpicppsori...

# %% [markdown]
# ## Convert Fitzpatrick CSV to Format
#
# Convert the Fitzpatrick metadata csv to the proper format and merge with existing metadata file.

# %%
# filter raw csv
image_blobs = bucket.list_blobs(prefix="raw/fitzpatrick17k/images")

image_filenames = []
for blob in image_blobs:
    image_filenames.append(blob.name)

# get image hashes we have
image_filenames_ser = pd.Series(image_filenames)
image_hashes = image_filenames_ser.str.replace("raw/fitzpatrick17k/images/", "")
image_hashes = image_hashes.apply(lambda x: re.sub(r'\.[^/.]+$', '', x))

# filter metadata to only include images we have
fitz_csv_filt_tmp = fitz_meta_csv[fitz_meta_csv['md5hash'].isin(image_hashes)]
print(fitz_csv_filt_tmp.shape)
fitz_csv_filt_tmp.head()
# Out:
# (3905, 9)
#                                 md5hash  fitzpatrick_scale  \
# 12672  119d712798a653799adaf8e5e08ce66e                  4
# 12673  23575178ed245ee186aa5f64c94b48d9                  3
# 12674  8afc38b0f9946c000acd5f36e0c85642                  2
# 12675  89e55bbc7452d465218e6c6723c07ce0                  2
# 12676  c78bde4a058f64a6d2fe762ae2800176                  3
#
#        fitzpatrick_centaur                                     label  \
# 12672                    3                     hailey hailey disease
# 12673                    3  papilomatosis confluentes and reticulate
# 12674                    5                                   scabies
# 12675                    3                        tuberous sclerosis
# 12676                    4                                    keloid
#
#       nine_partition_label three_partition_label   qc  \
# 12672       genodermatoses        non-neoplastic  NaN
# 12673         inflammatory        non-neoplastic  NaN
# 12674         inflammatory        non-neoplastic  NaN
# 12675       genodermatoses        non-neoplastic  NaN
# 12676         inflammatory        non-neoplastic  NaN
#
#                                                      url  \
# 12672  http://atlasdermatologico.com.br/img?imageId=2409
# 12673  http://atlasdermatologico.com.br/img?imageId=5060
# 12674  http://atlasdermatologico.com.br/img?imageId=4898
# 12675  http://atlasdermatologico.com.br/img?imageId=7598
# 12676  http://atlasdermatologico.com.br/img?imageId=2969
#
#                                            url_alphanum
# 12672  httpwwwatlasdermatologicocombrimgimageId2409.jpg
# 12673  httpwwwatlasdermatologicocombrimgimageId5060.jpg
# 12674  httpwwwatlasdermatologicocombrimgimageId4898.jpg
# 12675  httpwwwatlasdermatologicocombrimgimageId7598.jpg
# 12676  httpwwwatlasdermatologicocombrimgimageId2969.jpg

# %%
# format data to match what Tanush put in bucket
fitz_final_metadata = pd.DataFrame()
fitz_final_metadata["image_id"] = fitz_csv_filt_tmp["md5hash"]
fitz_final_metadata["unharmonized_label"] = fitz_csv_filt_tmp["label"]
fitz_final_metadata["dataset"] = ["fitzpatrick17k"] * fitz_final_metadata.shape[0]
fitz_final_metadata["save_name"] = fitz_final_metadata["dataset"] + '_' + fitz_final_metadata["image_id"]
fitz_final_metadata["confidence"] = fitz_csv_filt_tmp["qc"]

print(fitz_final_metadata.shape)
fitz_final_metadata.head()
# Out:
# (3905, 5)
#                                image_id  \
# 12672  119d712798a653799adaf8e5e08ce66e
# 12673  23575178ed245ee186aa5f64c94b48d9
# 12674  8afc38b0f9946c000acd5f36e0c85642
# 12675  89e55bbc7452d465218e6c6723c07ce0
# 12676  c78bde4a058f64a6d2fe762ae2800176
#
#                              unharmonized_label         dataset  \
# 12672                     hailey hailey disease  fitzpatrick17k
# 12673  papilomatosis confluentes and reticulate  fitzpatrick17k
# 12674                                   scabies  fitzpatrick17k
# 12675                        tuberous sclerosis  fitzpatrick17k
# 12676                                    keloid  fitzpatrick17k
#
#                                              save_name confidence
# 12672  fitzpatrick17k_119d712798a653799adaf8e5e08ce66e        NaN
# 12673  fitzpatrick17k_23575178ed245ee186aa5f64c94b48d9        NaN
# 12674  fitzpatrick17k_8afc38b0f9946c000acd5f36e0c85642        NaN
# 12675  fitzpatrick17k_89e55bbc7452d465218e6c6723c07ce0        NaN
# 12676  fitzpatrick17k_c78bde4a058f64a6d2fe762ae2800176        NaN

# %%
# concatenate datasets
print(f"Expected total rows after combine: {meta_csv.shape[0] + fitz_final_metadata.shape[0]}")

full_meta = pd.concat([meta_csv, fitz_final_metadata], axis=0, ignore_index=True)
# in case we already uploaded the metadata and are running again, drop duplicates so we don't upload it twice
# each image should have a unique ID and dataset combination, so drop any image with duplicates for these
full_meta = full_meta.drop_duplicates(subset = ["image_id", "dataset"], ignore_index=True)
print(f"Shape of full metadata: {full_meta.shape}")
full_meta.head()
# Out:
# Expected total rows after combine: 10422
# Shape of full metadata: (10410, 6)
#    Unnamed: 0              image_id  \
# 0         0.0  -3205742176803893704
# 1         1.0  -4762289084741430925
# 2         2.0  -4027806997035329030
# 3         3.0  -3799298995660217860
# 4         4.0  -5881426422999442186
#
#                                   unharmonized_label dataset confidence  \
# 0                     Inflicted skin lesions, Eczema    SCIN          4
# 1                       Prurigo nodularis, SCC/SCCIS    SCIN          4
# 2                                           Impetigo    SCIN          2
# 3  Lichen planus/lichenoid eruption, Folliculitis...    SCIN          1
# 4  Lichen planus/lichenoid eruption, Folliculitis...    SCIN          1
#
#                    save_name
# 0  SCIN_-3205742176803893704
# 1  SCIN_-4762289084741430925
# 2  SCIN_-4027806997035329030
# 3  SCIN_-3799298995660217860
# 4  SCIN_-5881426422999442186

# %%
# save to bucket
# full_meta = full_meta.drop('Unnamed: 0', axis=1)
# full_meta.to_csv("metadata.csv", index=False)

# meta_csv_upload_blob = bucket.blob(os.path.join(FINAL_PATH, 'metadata_tmp.csv'))
# blob.upload_from_filename('metadata.csv')

# full_meta.head()
